# %% [markdown]
# # The Full Pipeline for Exploiting Loop-Like Exercices in The Classification of Parkinson's Disease

# %%
from dataaccess.filedatareader import FileDataReader

reader = FileDataReader('../data/Patients Records 05_04_2019')
info, data = reader.load_french(tasks=[3])
# Out:
# Loading the data, please wait.
# Data loaded successfully.

# %%
from datamanipulation.datageneration import get_pd_hc_only, match_age_gender_pd
info, data = get_pd_hc_only(info, data)
info, data = match_age_gender_pd(info, data)
data.sort_index(inplace=True)

# %%
from datamanipulation.extraction import *
extracted = extract_features(data)
# Out:
# Started extracting features.
# The following features were extracted successfully: ['Displacement x', 'Displacement y', 'Distance x', 'Distance y', 'Distance x-y', 'Velocity x', 'Velocity y', 'Velocity x-y', 'Acceleration x', 'Acceleration y', 'Acceleration x-y', 'Jerk x', 'Jerk y', 'Jerk x-y', 'ROC p / time', 'ROC al / time', 'ROC az / time', 'Slope', 'Slant']
# Number of features: 19

# %%
standardized = extracted.copy()
for col in standardized.columns[1:]:
    mean = standardized[col].mean()
    std = standardized[col].std()
    standardized[col] = (standardized[col] - mean) / std

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '2'
from datamanipulation.datageneration import get_samples
from tensorflow.keras.preprocessing.sequence import pad_sequences
X, y = get_samples(standardized, 'PD')
padding_val = 0
X_padded = pad_sequences(X, dtype='float32', padding='post', value=padding_val)
# Out:
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
from sklearn.model_selection import train_test_split
stratify_with=standardized.groupby(['ID', 'Language', 'Task']).first().merge(info, on='ID')[['PD_x', 'Gender']]
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, stratify=stratify_with, random_state=42, test_size=0.25)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '2'
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dropout, Dense, Masking
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, confusion_matrix

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

confusions = []

for train_index, val_index in kf.split(X_train, y_train):
    X_train_cv, X_val = X_train[train_index], X_train[val_index]
    y_train_cv, y_val = y_train[train_index], y_train[val_index]

    # cnn
    model = Sequential()
    model.add(Masking(mask_value=padding_val, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Conv1D(32, 3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(64, 3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(64, 3, activation='relu'))
    
    # fcl
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification
    
    # compilation
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # training
    model.fit(X_train_cv, y_train_cv, epochs=6, batch_size=5, validation_data=(X_val, y_val))

    # evaluation on validation set
    y_pred = (model.predict(X_val) > 0.5).astype(int)
    confusion = confusion_matrix(y_val, y_pred)
    confusions.append(confusion)

confusions = np.array(confusions)
mean_conf = np.array([
    [confusions[:,0,0].sum()/confusions.shape[0], confusions[:,0,1].sum()/confusions.shape[0]],
    [confusions[:,1,0].sum()/confusions.shape[0], confusions[:,1,1].sum()/confusions.shape[0]]
])
tn, fp, fn, tp = mean_conf.reshape(-1)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
accuracy = (tp + tn) / mean_conf.sum()
print('The mean accuracy, sensitivity and specificity over the 5 iterations of the 5 fold stratified cross validation:\n', accuracy, sensitivity, specificity)
# Out:
# Epoch 1/6
# 5/5 [==============================] - 2s 210ms/step - loss: 0.6498 - accuracy: 0.4583 - val_loss: 0.6379 - val_accuracy: 0.5000
# Epoch 2/6
# 5/5 [==============================] - 1s 186ms/step - loss: 0.2188 - accuracy: 1.0000 - val_loss: 0.6974 - val_accuracy: 0.5000
# Epoch 3/6
# 5/5 [==============================] - 1s 149ms/step - loss: 0.1613 - accuracy: 0.9583 - val_loss: 0.8185 - val_accuracy: 0.5000
# Epoch 4/6
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0914 - accuracy: 0.9583 - val_loss: 0.8805 - val_accuracy: 0.5000
# Epoch 5/6
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0691 - accuracy: 0.9583 - val_loss: 0.9339 - val_accuracy: 0.5000
# Epoch 6/6
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.9849 - val_accuracy: 0.5000
# 1/1 [==============================] - 0s 172ms/step
# Epoch 1/6
# 5/5 [==============================] - 2s 207ms/step - loss: 0.7841 - accuracy: 0.5417 - val_loss: 0.4786 - val_accuracy: 0.8333
# Epoch 2/6
# 5/5 [==============================] - 1s 145ms/step - loss: 0.3481 - accuracy: 0.9167 - val_loss: 0.4615 - val_accuracy: 0.8333
# Epoch 3/6
# 5/5 [==============================] - 1s 151ms/step - loss: 0.2018 - accuracy: 0.8750 - val_loss: 0.6264 - val_accuracy: 0.6667
# Epoch 4/6
# 5/5 [==============================] - 1s 170ms/step - loss: 0.1199 - accuracy: 0.9583 - val_loss: 0.6474 - val_accuracy: 0.6667
# Epoch 5/6
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 0.6011 - val_accuracy: 0.8333
# Epoch 6/6
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.6146 - val_accuracy: 0.8333
# 1/1 [==============================] - 0s 175ms/step
# Epoch 1/6
# 5/5 [==============================] - 2s 212ms/step - loss: 0.7445 - accuracy: 0.5000 - val_loss: 0.3553 - val_accuracy: 0.8333
# Epoch 2/6
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3941 - accuracy: 0.7500 - val_loss: 0.3715 - val_accuracy: 0.8333
# Epoch 3/6
# 5/5 [==============================] - 1s 185ms/step - loss: 0.3035 - accuracy: 0.8333 - val_loss: 0.2597 - val_accuracy: 0.8333
# Epoch 4/6
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1712 - accuracy: 0.9583 - val_loss: 0.2178 - val_accuracy: 1.0000
# Epoch 5/6
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1200 - accuracy: 0.9583 - val_loss: 0.2128 - val_accuracy: 1.0000
# Epoch 6/6
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0825 - accuracy: 0.9583 - val_loss: 0.2068 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 87ms/step
# Epoch 1/6
# 5/5 [==============================] - 2s 195ms/step - loss: 1.1065 - accuracy: 0.4583 - val_loss: 0.3990 - val_accuracy: 1.0000
# Epoch 2/6
# 5/5 [==============================] - 1s 146ms/step - loss: 0.4562 - accuracy: 0.8333 - val_loss: 0.3473 - val_accuracy: 0.8333
# Epoch 3/6
# 5/5 [==============================] - 1s 150ms/step - loss: 0.3660 - accuracy: 0.8750 - val_loss: 0.2976 - val_accuracy: 0.8333
# Epoch 4/6
# 5/5 [==============================] - 1s 150ms/step - loss: 0.2622 - accuracy: 0.8750 - val_loss: 0.2632 - val_accuracy: 0.8333
# Epoch 5/6
# 5/5 [==============================] - 1s 158ms/step - loss: 0.2039 - accuracy: 0.9583 - val_loss: 0.2491 - val_accuracy: 1.0000
# Epoch 6/6
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1578 - accuracy: 0.9583 - val_loss: 0.2527 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 165ms/step
# Epoch 1/6
# 5/5 [==============================] - 2s 211ms/step - loss: 0.6843 - accuracy: 0.5833 - val_loss: 0.4956 - val_accuracy: 0.6667
# Epoch 2/6
# 5/5 [==============================] - 1s 180ms/step - loss: 0.2697 - accuracy: 0.9583 - val_loss: 0.5698 - val_accuracy: 0.6667
# Epoch 3/6
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1224 - accuracy: 1.0000 - val_loss: 0.5934 - val_accuracy: 0.6667
# Epoch 4/6
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.6733 - val_accuracy: 0.6667
# Epoch 5/6
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.7711 - val_accuracy: 0.6667
# Epoch 6/6
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.8476 - val_accuracy: 0.6667
# 1/1 [==============================] - 0s 168ms/step
# The mean accuracy, sensitivity and specificity over the 5 iterations of the 5 fold stratified cross validation:
#  0.8000000000000002 0.7333333333333334 0.8666666666666667

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '2'
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Masking
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, confusion_matrix

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

confusions = []

for train_index, val_index in kf.split(X_train, y_train):
    X_train_cv, X_val = X_train[train_index], X_train[val_index]
    y_train_cv, y_val = y_train[train_index], y_train[val_index]

    # cnn
    model = Sequential()
    model.add(Masking(mask_value=padding_val, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Conv1D(25, 25, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(25, 25, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(25, 25, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(25, 25, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(25, 25, activation='relu'))
    
    # fcl
    model.add(Flatten())
    #model.add(Dense(25, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification
    
    # compilation
    model.compile(optimizer=Adam(learning_rate=0.0005),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # training
    model.fit(X_train_cv, y_train_cv, epochs=10, batch_size=30, validation_data=(X_val, y_val))

    # evaluation on validation set
    y_pred = (model.predict(X_val) > 0.5).astype(int)
    confusion = confusion_matrix(y_val, y_pred)
    confusions.append(confusion)

confusions = np.array(confusions)
mean_conf = np.array([
    [confusions[:,0,0].sum()/confusions.shape[0], confusions[:,0,1].sum()/confusions.shape[0]],
    [confusions[:,1,0].sum()/confusions.shape[0], confusions[:,1,1].sum()/confusions.shape[0]]
])
tn, fp, fn, tp = mean_conf.reshape(-1)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
accuracy = (tp + tn) / mean_conf.sum()
print('The mean accuracy, sensitivity and specificity over the 5 iterations of the 5 fold stratified cross validation:\n', accuracy, sensitivity, specificity)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.6842 - accuracy: 0.5417 - val_loss: 0.6593 - val_accuracy: 0.8333
# Epoch 2/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.5635 - accuracy: 0.8750 - val_loss: 0.6374 - val_accuracy: 0.6667
# Epoch 3/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.4590 - accuracy: 0.8750 - val_loss: 0.6249 - val_accuracy: 0.6667
# Epoch 4/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.3561 - accuracy: 0.8750 - val_loss: 0.6471 - val_accuracy: 0.6667
# Epoch 5/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.2706 - accuracy: 0.8750 - val_loss: 0.6927 - val_accuracy: 0.6667
# Epoch 6/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.2172 - accuracy: 0.9167 - val_loss: 0.7254 - val_accuracy: 0.6667
# Epoch 7/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.1910 - accuracy: 0.9167 - val_loss: 0.7370 - val_accuracy: 0.6667
# Epoch 8/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.1756 - accuracy: 0.9583 - val_loss: 0.7429 - val_accuracy: 0.6667
# Epoch 9/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.1545 - accuracy: 0.9583 - val_loss: 0.7374 - val_accuracy: 0.6667
# Epoch 10/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.1292 - accuracy: 0.9583 - val_loss: 0.7213 - val_accuracy: 0.6667
# 1/1 [==============================] - 0s 170ms/step
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7117 - accuracy: 0.4583 - val_loss: 0.5675 - val_accuracy: 0.8333
# Epoch 2/10
# 1/1 [==============================] - 1s 904ms/step - loss: 0.5641 - accuracy: 0.7500 - val_loss: 0.5004 - val_accuracy: 1.0000
# Epoch 3/10
# 1/1 [==============================] - 1s 743ms/step - loss: 0.4545 - accuracy: 0.8333 - val_loss: 0.4290 - val_accuracy: 1.0000
# Epoch 4/10
# 1/1 [==============================] - 1s 695ms/step - loss: 0.3551 - accuracy: 0.8333 - val_loss: 0.3725 - val_accuracy: 0.8333
# Epoch 5/10
# 1/1 [==============================] - 1s 610ms/step - loss: 0.2862 - accuracy: 0.8333 - val_loss: 0.3892 - val_accuracy: 0.6667
# Epoch 6/10
# 1/1 [==============================] - 1s 600ms/step - loss: 0.2563 - accuracy: 0.9167 - val_loss: 0.4525 - val_accuracy: 0.6667
# Epoch 7/10
# 1/1 [==============================] - 1s 613ms/step - loss: 0.2466 - accuracy: 0.9167 - val_loss: 0.4270 - val_accuracy: 0.6667
# Epoch 8/10
# 1/1 [==============================] - 1s 668ms/step - loss: 0.2225 - accuracy: 0.9167 - val_loss: 0.3433 - val_accuracy: 0.8333
# Epoch 9/10
# 1/1 [==============================] - 1s 789ms/step - loss: 0.1873 - accuracy: 0.9167 - val_loss: 0.2783 - val_accuracy: 0.8333
# Epoch 10/10
# 1/1 [==============================] - 1s 744ms/step - loss: 0.1576 - accuracy: 0.9583 - val_loss: 0.2528 - val_accuracy: 0.8333
# 1/1 [==============================] - 0s 190ms/step
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7065 - accuracy: 0.5000 - val_loss: 0.7072 - val_accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 1s 652ms/step - loss: 0.5933 - accuracy: 0.8333 - val_loss: 0.6335 - val_accuracy: 0.6667
# Epoch 3/10
# 1/1 [==============================] - 1s 760ms/step - loss: 0.5101 - accuracy: 0.8750 - val_loss: 0.5434 - val_accuracy: 0.8333
# Epoch 4/10
# 1/1 [==============================] - 1s 998ms/step - loss: 0.4270 - accuracy: 0.9167 - val_loss: 0.4286 - val_accuracy: 0.8333
# Epoch 5/10
# 1/1 [==============================] - 1s 957ms/step - loss: 0.3508 - accuracy: 0.9167 - val_loss: 0.3154 - val_accuracy: 0.8333
# Epoch 6/10
# 1/1 [==============================] - 1s 858ms/step - loss: 0.2898 - accuracy: 0.8750 - val_loss: 0.2377 - val_accuracy: 0.8333
# Epoch 7/10
# 1/1 [==============================] - 1s 830ms/step - loss: 0.2442 - accuracy: 0.9167 - val_loss: 0.1801 - val_accuracy: 0.8333
# Epoch 8/10
# 1/1 [==============================] - 1s 901ms/step - loss: 0.2006 - accuracy: 0.9167 - val_loss: 0.1295 - val_accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 1s 849ms/step - loss: 0.1595 - accuracy: 0.9583 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 1s 888ms/step - loss: 0.1267 - accuracy: 0.9583 - val_loss: 0.0846 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 118ms/step
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7376 - accuracy: 0.4167 - val_loss: 0.6497 - val_accuracy: 0.8333
# Epoch 2/10
# 1/1 [==============================] - 1s 746ms/step - loss: 0.6223 - accuracy: 0.7917 - val_loss: 0.5936 - val_accuracy: 0.8333
# Epoch 3/10
# 1/1 [==============================] - 1s 810ms/step - loss: 0.5414 - accuracy: 0.8750 - val_loss: 0.5168 - val_accuracy: 0.8333
# Epoch 4/10
# 1/1 [==============================] - 1s 882ms/step - loss: 0.4620 - accuracy: 0.8750 - val_loss: 0.4209 - val_accuracy: 1.0000
# Epoch 5/10
# 1/1 [==============================] - 1s 951ms/step - loss: 0.3883 - accuracy: 0.8750 - val_loss: 0.3274 - val_accuracy: 1.0000
# Epoch 6/10
# 1/1 [==============================] - 1s 891ms/step - loss: 0.3351 - accuracy: 0.8750 - val_loss: 0.2549 - val_accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 1s 939ms/step - loss: 0.3045 - accuracy: 0.8750 - val_loss: 0.2093 - val_accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 1s 742ms/step - loss: 0.2806 - accuracy: 0.8750 - val_loss: 0.1831 - val_accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 1s 852ms/step - loss: 0.2505 - accuracy: 0.8750 - val_loss: 0.1715 - val_accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 1s 776ms/step - loss: 0.2171 - accuracy: 0.9167 - val_loss: 0.1692 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 117ms/step
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.6874 - accuracy: 0.4583 - val_loss: 0.6678 - val_accuracy: 0.5000
# Epoch 2/10
# 1/1 [==============================] - 1s 756ms/step - loss: 0.5696 - accuracy: 0.8333 - val_loss: 0.5890 - val_accuracy: 0.5000
# Epoch 3/10
# 1/1 [==============================] - 1s 856ms/step - loss: 0.4565 - accuracy: 0.8750 - val_loss: 0.4974 - val_accuracy: 0.6667
# Epoch 4/10
# 1/1 [==============================] - 1s 907ms/step - loss: 0.3416 - accuracy: 0.9167 - val_loss: 0.4470 - val_accuracy: 0.6667
# Epoch 5/10
# 1/1 [==============================] - 1s 901ms/step - loss: 0.2494 - accuracy: 0.9583 - val_loss: 0.4947 - val_accuracy: 0.6667
# Epoch 6/10
# 1/1 [==============================] - 1s 859ms/step - loss: 0.1847 - accuracy: 0.9583 - val_loss: 0.6647 - val_accuracy: 0.6667
# Epoch 7/10
# 1/1 [==============================] - 1s 823ms/step - loss: 0.1353 - accuracy: 1.0000 - val_loss: 0.9223 - val_accuracy: 0.6667
# Epoch 8/10
# 1/1 [==============================] - 1s 856ms/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 1.2321 - val_accuracy: 0.6667
# Epoch 9/10
# 1/1 [==============================] - 1s 882ms/step - loss: 0.0563 - accuracy: 1.0000 - val_loss: 1.5982 - val_accuracy: 0.6667
# Epoch 10/10
# 1/1 [==============================] - 1s 864ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 2.0087 - val_accuracy: 0.6667
# 1/1 [==============================] - 0s 117ms/step
# The mean accuracy, sensitivity and specificity over the 5 iterations of the 5 fold stratified cross validation:
#  0.8333333333333334 0.7999999999999999 0.8666666666666667

# %% [markdown]
# use these guys next: 'French Level Written', 'Writing Frequency', 'Age', 'Gender'

# %%
model = ?
y_pred = (model.predict(X_test) > 0.5).astype(int)
confusion = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = confusion.reshape(-1)
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
accuracy = (tp + tn) / confusion.sum()
print('accuracy, sensitivity, specificity:', accuracy, sensitivity, specificity)
# Out:
#   Cell In[64], line 1
#     model = ?
#             ^
# SyntaxError: invalid syntax
